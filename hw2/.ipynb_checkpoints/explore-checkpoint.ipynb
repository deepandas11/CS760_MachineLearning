# %%
import pandas as pd
from sklearn import tree
import numpy as np
import DecisionTree as DT
import scipy.stats as st

# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def load_data(datafile):
    data = np.genfromtxt(datafile)
    X = []
    Y = []
    for row in data:
        X.append(row[:-1])
        Y.append(row[-1])
    X = np.array(X)
    Y = np.array(Y)
    return X,Y, data

# %%
x,y,data1 = load_data("D1.txt")
data1
# Out:
# array([[0.264185, 0.178456, 0.      ],
#        [0.409499, 0.213456, 1.      ],
#        [0.926224, 0.540329, 1.      ],
#        ...,
#        [0.285166, 0.956678, 1.      ],
#        [0.751571, 0.514041, 1.      ],
#        [0.142654, 0.226182, 1.      ]])

# %%
df1 = DT.load_data("D1.txt")
df1
# Out:
#            x1        x2  Outcome
# 0    0.264185  0.178456        0
# 1    0.409499  0.213456        1
# 2    0.926224  0.540329        1
# 3    0.573685  0.282145        1
# 4    0.953159  0.608121        1
# ..        ...       ...      ...
# 995  0.211320  0.737143        1
# 996  0.625005  0.233578        1
# 997  0.285166  0.956678        1
# 998  0.751571  0.514041        1
# 999  0.142654  0.226182        1
#
# [1000 rows x 3 columns]

# %%
cols = ['x1', 'x2']
DT.num_class(df1, "Outcome")
# Out:
# (825, 175)

# %%
root = DT.build_tree(df1, cols, "Outcome")

# %%
DT.print_tree(root, 0)
# Out:
# x2 0.201829
# 1 None
# 0 None

# %%
clf = tree.DecisionTreeClassifier("entropy")
clf.fit(df1[["x1","x2"]], df1["Outcome"])
tree.plot_tree(clf)
# Out:
# [Text(167.4, 163.07999999999998, 'X[1] <= 0.201\nentropy = 0.669\nsamples = 1000\nvalue = [175, 825]'),
#  Text(83.7, 54.360000000000014, 'entropy = 0.0\nsamples = 175\nvalue = [175, 0]'),
#  Text(251.10000000000002, 54.360000000000014, 'entropy = 0.0\nsamples = 825\nvalue = [0, 825]')]

# %%
# D1.txt


col = {0: 'r', 1:'b'}
for row in data1:
    plt.scatter(row[0], row[1], c=col[row[-1]])
    
xr = np.linspace(0,1,20)
yr = [0.201829 for _ in xr]
plt.xlabel("x1")
plt.ylabel("x2")
plt.grid(True)
plt.plot(xr, yr, 'g', linewidth=4)
plt.title("Scatter Plot for D1.txt. Blue = Label 1, Red = Label 0")
plt.show()

# %%
plt.style.use('ggplot')
